# %% [markdown]
# # Practicumopdrachten Week 2.3 (eerste kans)

# %% [markdown]
# ## Dependencies importeren

# %% [markdown]
# Kopieer in het codeblok hieronder van het vorige practicum de import-code voor de dependencies die het vaakst worden gebruikt om data in te lezen. Geef er ook de gebruikelijke aliassen aan.<br>
# Zet eventuele warnings uit.

# %%
import warnings
warnings.simplefilter('ignore')
import pandas as pd
import numpy as np
import sqlite3

# %% [markdown]
# Zet het bestand go_sales.sqlite in hetzelfde mapje als dit notebook.

# %% [markdown]
# ## Databasetabellen inlezen

# %% [markdown]
# Kopieer in het codeblok hieronder van het vorige practicum de code om een connectie met het bestand go_sales.sqlite te maken.

# %%
db = sqlite3.connect("Databases/GreatOutdoors/go_sales.sqlite")

# %% [markdown]
# Lees van de ingelezen go_sales-database te volgende tabellen in met behulp van "SELECT * FROM *tabel*".
# - product
# - product_type
# - product_line
# - sales_staff
# - sales_branch
# - retailer_site
# - country
# - order_header
# - order_details
# - target
# - returned_item
# - return_reason

# %%
product = pd.read_sql_query("SELECT * FROM product;", db)
country = pd.read_sql_query("SELECT * FROM country;", db)
sales_branch = pd.read_sql_query("SELECT * FROM sales_branch;", db)
retailer_site = pd.read_sql_query("SELECT * FROM retailer_site;", db)
product_type = pd.read_sql_query("SELECT * FROM product_type;", db)
returns = pd.read_sql_query("SELECT * FROM returned_item;", db)
order_details = pd.read_sql_query("SELECT * FROM order_details;", db)
sales_staff = pd.read_sql_query("SELECT * FROM sales_staff;", db)
order_header = pd.read_sql_query("SELECT * FROM order_header;", db)
returned_item  = pd.read_sql_query("SELECT * FROM returned_item;", db)
return_reason  = pd.read_sql_query("SELECT * FROM return_reason;", db)
target = pd.read_sql_query("SELECT * FROM SALES_TARGETData;", db)

# %% [markdown]
# Let op! Voor alle onderstaande opdrachten mag je <u>alleen Python</u> gebruiken, <u>geen SQL!</u>

# %% [markdown]
# ## Selecties op één tabel zonder functies

# %% [markdown]
# Geef een overzicht met daarin de producten en hun productiekosten waarvan de productiekosten lager dan 100 dollar en hoger dan 50 dollar ligt. (2 kolommen, 23 rijen)

# %%
# product
# product['PRODUCTION_COST'].astype(np.double)
product['PRODUCTION_COST'] = product["PRODUCTION_COST"].astype("double")

filtered_production_price = (product['PRODUCTION_COST'] > 50) & (product['PRODUCTION_COST'] < 100)

product.loc[(filtered_production_price), ['PRODUCT_NAME', 'PRODUCTION_COST']]
# Out:
#                        PRODUCT_NAME  PRODUCTION_COST
# 13                Blue Steel Putter            60.00
# 14            Blue Steel Max Putter            81.80
# 17              Course Pro Golf Bag            80.00
# 24                  Hibernator Lite            60.00
# 25                       Hibernator            86.00
# 28  Hibernator Self - Inflating Mat            78.55
# 31              Hibernator Camp Cot            65.33
# 32     Canyon Mule Climber Backpack            62.50
# 56          Granite Climbing Helmet            52.86
# 58            Husky Harness Extreme            55.00
# 69                   Granite Hammer            57.13
# 71        TrailChef Deluxe Cook Set            85.11
# 81                        Polar Ice            73.33
# 83                     Polar Sports            80.00
# 84                       Polar Wave            60.00
# 85                    Polar Extreme            72.50
# 88                     Edge Extreme            80.00
# ...

# %% [markdown]
# Geef een overzicht met daarin de producten en hun marge waarvan de marge lager dan 20 % of hoger dan 60 % ligt. (2 kolommen, 7 rijen)

# %%
# product['PRODUCTION_COST'] = product["PRODUCTION_COST"].astype("double")
product['MARGIN'] = product["MARGIN"].astype("float")

marge_filter = (product['MARGIN'] < .2) | (product['MARGIN'] > .6)
product.loc[(marge_filter), :]
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE  PRODUCTION_COST  \
# 29              21         15-2-2011                 3            29.17
# 32              24          5-3-2013                 4            62.50
# 100             86         15-2-2011                15             2.00
# 101             87         15-2-2011                15             2.00
# 102             88         15-2-2011                15             2.00
# 103             89         15-2-2011                15             2.50
# 105             90         15-2-2011                15             2.50
#
#      MARGIN   PRODUCT_IMAGE LANGUAGE                  PRODUCT_NAME  \
# 29     0.17   P21CE1SB3.jpg       EN                Hibernator Pad
# 32     0.17   P24CE1PK4.jpg       EN  Canyon Mule Climber Backpack
# 100    0.67  P86OP4IR15.jpg       EN             BugShield Natural
# 101    0.67  P86OP4IR15.jpg       EN               BugShield Spray
# ...

# %% [markdown]
# Geef een overzicht met daarin de landen waar met francs wordt betaald. Sorteer de uitkomst op land.  (1 kolom, 3 rijen)

# %%
francs_countries = country['CURRENCY_NAME'] == 'francs'
country.loc[(francs_countries), :].sort_values(by=['COUNTRY'])
# Out:
#    COUNTRY_CODE      COUNTRY LANGUAGE CURRENCY_NAME TRIAL879
# 7            17      Belgium       EN        francs        T
# 0             1       France       EN        francs        T
# 19            8  Switzerland       EN        francs        T

# %% [markdown]
# Geef een overzicht met daarin de verschillende introductiedatums waarop producten met meer dan 50% marge worden geïntroduceerd (1 kolom, 7 rijen)

# %%
product['MARGIN'] = product["MARGIN"].astype("float")

marge_filter = product['MARGIN'] > .5
product.loc[(marge_filter), ["INTRODUCTION_DATE"]].drop_duplicates()
# Out:
#     INTRODUCTION_DATE
# 4          10-12-2019
# 6          18-12-2019
# 7          27-12-2019
# 9           13-1-2020
# 14         15-12-2019
# 79         26-10-2016
# 100         15-2-2011

# %% [markdown]
# Geef een overzicht met daarin het eerste adres en de stad van verkoopafdelingen waarvan zowel het tweede adres als de regio bekend is (2 kolommen, 28 rijen)

# %%
sales_branch

sales_branch.loc[:, ["ADDRESS1", "ADDRESS2"]]
# Out:
#                             ADDRESS1           ADDRESS2
# 0                     Schwabentor 35               None
# 1                   Leopoldstraße 36               None
# 2                Isafjordsgatan 30 C               None
# 3       7800, 756 - 6th Avenue. S.W.               None
# 4                   789 Yonge Street               None
# 5             1288 Dorchester Avenue               None
# 6                    299 Yale Avenue               None
# 7         1288 South Barrington Ave.               None
# 8                     10032 NW 186th               None
# 9                6c, rue de l'Église               None
# 10  Prol. Paseo de la Reforma No. 51  Lomas de Santa Fe
# 11               202-2-3 Hyakunincho        Shinjuku-ku
# 12                     543-225 Asahi           Asahi-ku
# 13                  2315 Queen's Ave            Level 2
# 14     Plaza de la Constitución, s/n               None
# 15             Avenida Paulista, 333   CJ 231 2o. Andar
# ...

# %% [markdown]
# Geef een overzicht met daarin de landen waar met dollars (dollars of new dollar) wordt betaald. Sorteer de uitkomst op land. (1 kolom, 4 rijen)

# %%
dollars_countries = (country['CURRENCY_NAME'] == 'dollars') | (country['CURRENCY_NAME'] == 'new dollar')
country.loc[(dollars_countries), ["COUNTRY"]].sort_values(by=['COUNTRY'])
# Out:
#           COUNTRY
# 6       Australia
# 15         Canada
# 3          Taiwan
# 14  United States

# %% [markdown]
# Geef een overzicht met daarin beide adressen en de stad van vestigingen van klanten waarvan de postcode begint met een ‘D’ (van duitsland). Filter op vestigingen die een tweede adres hebben. (3 kolommen, 2 rijen)

# %%
filter = (retailer_site['POSTAL_ZONE'].str[0] == "D") & (retailer_site['ADDRESS2'].notna())
retailer_site.loc[filter, ["ADDRESS1", "ADDRESS2", "CITY"]]
# Out:
#              ADDRESS1       ADDRESS2       CITY
# 205  Röntgenstraße 90  3. Tür rechts  Frankfurt
# 351   Grubesallee 141       4. Stock    Hamburg

# %% [markdown]
# ## Selecties op één tabel met functies

# %% [markdown]
# Geef het totaal aantal producten dat is teruggebracht (1 waarde)

# %%
returns["RETURN_QUANTITY"] = returns["RETURN_QUANTITY"].astype("int64")
returns["RETURN_QUANTITY"].sum()
# Out:
# 14306

# %% [markdown]
# Geef het aantal regio’s waarin verkoopafdelingen gevestigd zijn. (1 waarde)

# %%
# sales_branch["REGION"].notna()
not_empty_region = sales_branch["REGION"].notna()

sales_branch.loc[not_empty_region]["REGION"].count()
# Out:
# 15

# %% [markdown]
# Maak 3 variabelen:
# - Een met de laagste
# - Een met de hoogste
# - Een met de gemiddelde (afgerond op 2 decimalen)
#
# marge van producten (3 kolommen, 1 rij)

# %%
product['MARGIN'] = product['MARGIN'].astype("double")
laagste_marge = product['MARGIN'].min()
hoogste_marge = product['MARGIN'].max()
avg_marge = np.round(product['MARGIN'].agg(np.mean), 2)

frame = {
    "Laagste Marge": [laagste_marge],
    "Hoogste Marge": [hoogste_marge],
    "Avg Marge": [avg_marge],
}

pd.DataFrame(frame)
# Out:
#    Laagste Marge  Hoogste Marge  Avg Marge
# 0           0.17            0.7        0.4

# %% [markdown]
# Geef het aantal vestigingen van klanten waarvan het 2e adres niet bekend is (1 waarde)

# %%
empty_address2 = sales_branch["ADDRESS2"].isna()

sales_branch.loc[empty_address2]['SALES_BRANCH_CODE'].count()
# Out:
# 19

# %% [markdown]
# Geef de gemiddelde kostprijs van de verkochte producten waarop korting (unit_sale_price < unit_price) is verleend (1 waarde)

# %%
avg_kostprijs = order_details["UNIT_SALE_PRICE"] < order_details["UNIT_PRICE"]


order_details["UNIT_PRICE"] = order_details["UNIT_PRICE"].astype("double")
order_details.loc[avg_kostprijs, "UNIT_PRICE"].agg(np.mean)
# Out:
# 192.88697889934417

# %% [markdown]
# Geef een overzicht met daarin het aantal medewerkers per medewerkersfunctie (2 kolommen, 7 rijen)

# %%
frame = pd.DataFrame()
roles = sales_staff["POSITION_EN"].drop_duplicates()

idx = 0
for role in roles:
    frame.at[idx,'role'] = role
    filter = sales_staff.loc[:, "POSITION_EN"].str.contains(role)
    frame.at[idx,'count'] = sales_staff.loc[filter, "POSITION_EN"].count()
    idx += 1
frame
# Out:
#                            role  count
# 0  Level 2 Sales Representative   39.0
# 1  Level 3 Sales Representative   24.0
# 2                Branch Manager   19.0
# 3               General Manager    1.0
# 4  Level 1 Sales Representative   13.0
# 5              Regional Manager    2.0
# 6              District Manager    4.0

# %% [markdown]
# Geef een overzicht met daarin per telefoonnummer het aantal medewerkers dat op dat telefoonnummer bereikbaar is. Toon alleen de telefoonnummer waarop meer dan 4 medewerkers bereikbaar zijn. (2 kolommen, 10 rijen)

# %%
s = sales_staff

s['Aantal werknemers'] = 0



f = s.groupby('WORK_PHONE', as_index=False)['Aantal werknemers'].count()

f.loc[f['Aantal werknemers'] > 4, :]
# Out:
#              WORK_PHONE  Aantal werknemers
# 4     +(44) 121 3505267                  5
# 10  +(61) 03 2982  4242                  5
# 11  +31 (0)20 692 93 94                  5
# 13    +33 1 68 94 52 20                  5
# 18     1 (206) 292-0012                  5
# 19     1 (305) 557-4810                  6
# 20     1 (310) 281-5722                  5
# 21     1 (403) 232-5986                  5
# 22     1 (416) 493-5595                  5
# 23     1 (617) 268-6754                  6

# %% [markdown]
# ## Selecties op meerdere tabellen zonder functies

# %% [markdown]
# Geef een overzicht met daarin het eerste adres en de stad van vestigingen van klanten uit ‘Netherlands’ (2 kolommen, 20 rijen)

# %%
merged_df = pd.merge(left=retailer_site, right=country, how='inner', left_on= 'COUNTRY_CODE', right_on='COUNTRY_CODE')

dutch_retailer_sites = merged_df["COUNTRY"] == "Netherlands"

merged_df.loc[dutch_retailer_sites, ['ADDRESS1', 'CITY']]
# Out:
#                       ADDRESS1          CITY
# 208                   Beets 36         Beets
# 209               Perestraat 1      Deventer
# 210  Laan van Meerdervoort 966      Den Haag
# 211             Kalfjeslaan 47    Amstelveen
# 212               Startbaan 11    Amstelveen
# 213      Noorderspoorsingel 28     Groningen
# 214              Hogehilweg 13     Amsterdam
# 215             Spoorstraat 43    Varsseveld
# 216             Westhavenweg 8     Amsterdam
# 217              Westzeedijk 4        Muiden
# 218            Gooiergracht 91         Laren
# 219            Hoofdstraat 150   Pieterburen
# 220                Olde Diek 2         Laren
# 221     Amsterdamsestraatweg 8      Maarssen
# 222        Krayenhoffstraat 11     Amsterdam
# 223         Overschiestraat 19     Amsterdam
# 224              Havenbuurt 12        Marken
# 225               Duivendaal 1    Wageningen
# 226              Voorstraat 37  Nieuweschans
# 227         Stadhouderslaan 18     Rotterdam

# %% [markdown]
# Geef een overzicht met daarin de productnamen die tot het producttype ‘Eyewear’ behoren. (1 kolom, 5 rijen)

# %%
merged_df_prod = pd.merge(left=product_type, right=product, how='inner', left_on= 'PRODUCT_TYPE_CODE', right_on='PRODUCT_TYPE_CODE')

eyewear_filter = merged_df_prod.loc[:, "PRODUCT_TYPE_EN"] == "Eyewear"

merged_df_prod.loc[eyewear_filter, ["PRODUCT_NAME"]]
# Out:
#      PRODUCT_NAME
# 15      Polar Sun
# 16      Polar Ice
# 17   Polar Sports
# 18     Polar Wave
# 19  Polar Extreme

# %% [markdown]
# Geef een overzicht met daarin alle unieke eerste adressen van klantvestigingen en de voornaam en achternaam van de verkopers die ‘Branch Manager’ zijn en aan deze vestigingen hebben verkocht (3 kolommen, 1 rij)

# %%
unieke_addressen = retailer_site.drop_duplicates("ADDRESS1")

s1_merge = pd.merge(left=order_header, right=sales_staff, how='inner', left_on='SALES_STAFF_CODE', right_on='SALES_STAFF_CODE')


s2_merge = pd.merge(left=s1_merge, right=retailer_site, how='inner', left_on='RETAILER_SITE_CODE', right_on='RETAILER_SITE_CODE')


f = s2_merge.loc[:, "POSITION_EN"] == "Branch Manager"


s2_merge.loc[f, ["FIRST_NAME", "LAST_NAME", "RETAILER_SITE_CODE"]].drop_duplicates(["FIRST_NAME", "LAST_NAME"])
# Out:
#      FIRST_NAME LAST_NAME RETAILER_SITE_CODE
# 3574     Bayard     Lopes                335

# %% [markdown]
# Geef een overzicht met daarin van de verkopers hun functie en indien zij iets hebben verkocht de datum waarop de verkoop heeft plaatsgevonden. Laat alleen de verschillende namen van de posities zien van de verkopers die het woord ‘Manager’ in hun positienaam hebben staan. (2 kolommen, 9 rijen)

# %%
s3_merge = pd.merge(left=sales_staff, right=order_header, how='left', left_on='SALES_STAFF_CODE', right_on='SALES_STAFF_CODE')
dupes_removed = s3_merge.drop_duplicates(["POSITION_EN", "ORDER_DATE"])
manager_filter = dupes_removed.loc[:, "POSITION_EN"].str.contains("Manager")
dupes_removed.loc[manager_filter, ["POSITION_EN", "ORDER_DATE"]]
# Out:
#            POSITION_EN  ORDER_DATE
# 421     Branch Manager         NaN
# 422    General Manager         NaN
# 1276  Regional Manager         NaN
# 1643  District Manager         NaN
# 5325    Branch Manager  2022-09-09
# 5326    Branch Manager  2022-10-31
# 5327    Branch Manager  2022-12-13
# 5328    Branch Manager  2022-03-13
# 5329    Branch Manager  2022-01-09

# %% [markdown]
# Geef een overzicht met daarin de verschillende namen van producten en bijbehorende namen van producttypen van de producten waarvoor ooit meer dan 750 stuks tegelijk verkocht zijn. (2 kolommen, 9 rijen)

# %%
s4_merge = pd.merge(left=product, right=product_type, how='left', left_on='PRODUCT_TYPE_CODE', right_on='PRODUCT_TYPE_CODE')
s5_merge = pd.merge(left=s4_merge, right=order_details, how='inner', left_on='PRODUCT_NUMBER', right_on='PRODUCT_NUMBER')

filter = s5_merge['QUANTITY'] > 750

s5_merge.loc[filter, ["PRODUCT_NAME", "PRODUCT_TYPE_EN"]].drop_duplicates(["PRODUCT_NAME", "PRODUCT_TYPE_EN"])
# Out:
#                 PRODUCT_NAME    PRODUCT_TYPE_EN
# 8616                Star Peg              Tents
# 15975              Firefly 2           Lanterns
# 37903        BugShield Spray  Insect Repellents
# 38313  BugShield Lotion Lite  Insect Repellents
# 38770       BugShield Lotion  Insect Repellents
# 39618      BugShield Extreme  Insect Repellents
# 40754         Sun Shelter 15          Sunscreen
# 41106         Sun Shelter 30          Sunscreen
# 41681             Sun Shield          Sunscreen

# %% [markdown]
# Geef een overzicht met daarin de productnamen waarvan ooit meer dan 40% korting is verleend. De formule voor korting is: (unit_price - unit_sale_price) / unit_price (1 kolom, 8 rijen)

# %%
merged = pd.merge(left=product, right=order_details, how='inner', left_on='PRODUCT_NUMBER', right_on='PRODUCT_NUMBER')

unit_price = merged['UNIT_PRICE'].astype("double")
sale_price = merged['UNIT_SALE_PRICE'].astype("double")

discount = ((unit_price - sale_price) / unit_price) > .4

merged.loc[discount, ["PRODUCT_NAME"]].drop_duplicates("PRODUCT_NAME")
# Out:
#                        PRODUCT_NAME
# 2765   Hailstorm Titanium Woods Set
# 37446             BugShield Natural
# 37967               BugShield Spray
# 38306         BugShield Lotion Lite
# 38772              BugShield Lotion
# 39561             BugShield Extreme
# 40799                Sun Shelter 15
# 41194                Sun Shelter 30

# %% [markdown]
# Geef een overzicht met daarin de retourreden van producten waarvan ooit meer dan 90% van de aangeschafte hoeveelheid is teruggebracht (return_quantity/quantity). (1 kolom, 3 rijen)

# %%
merged = pd.merge(left=order_details, right=returned_item, how='inner', left_on='ORDER_DETAIL_CODE', right_on='ORDER_DETAIL_CODE')
merged2 = pd.merge(left=merged, right=return_reason, how='inner', left_on='RETURN_REASON_CODE', right_on='RETURN_REASON_CODE')


return_quantity = merged2['RETURN_QUANTITY'].astype("double")
quantity = merged2['QUANTITY'].astype("double")

discount = (return_quantity / quantity) > .9

merged2.loc[discount, ["RETURN_DESCRIPTION_EN"]].drop_duplicates("RETURN_DESCRIPTION_EN")
# Out:
#      RETURN_DESCRIPTION_EN
# 0    Wrong product shipped
# 1   Unsatisfactory product
# 15   Wrong product ordered

# %% [markdown]
# ## Selecties op meerdere tabellen met functies

# %% [markdown]
# Geef een overzicht met daarin per producttype het aantal producten die tot dat producttype behoren. (2 kolommen, 21 rijen)

# %%
product_en_type =  pd.merge(left=product, right=product_type, how='inner', left_on='PRODUCT_TYPE_CODE', right_on='PRODUCT_TYPE_CODE')

f = product_en_type.groupby("PRODUCT_TYPE_CODE", as_index=False)["PRODUCT_NUMBER"].count().rename(columns= {"PRODUCT_NUMBER": "count"} )
f
# Out:
#    PRODUCT_TYPE_CODE  count
# 0                  1     10
# 1                 10      5
# 2                 11      5
# 3                 12      5
# 4                 13      4
# 5                 14      4
# 6                 15      5
# 7                 16      5
# 8                 17      5
# 9                 18      4
# 10                19      4
# 11                 2      6
# 12                20      3
# 13                21      4
# 14                 3      7
# 15                 4      6
# 16                 5     12
# 17                 6      4
# 18                 7      4
# 19                 8      7
# 20                 9      6

# %% [markdown]
# Geef een overzicht met daarin per land het aantal vestigingen van klanten die zich in dat land bevinden. (2 kolommen, 21 rijen)

# %%
landen =  pd.merge(left=country, right=retailer_site, how='inner', left_on='COUNTRY_CODE', right_on='COUNTRY_CODE')

p = landen.groupby("COUNTRY", as_index=False)["COUNTRY_CODE"].count().rename(columns= {"COUNTRY_CODE": "Hoeveelheid"} )
p
# Out:
#            COUNTRY  Hoeveelheid
# 0        Australia           10
# 1          Austria           10
# 2          Belgium           10
# 3           Brazil            1
# 4           Canada           31
# 5            China           10
# 6          Denmark            6
# 7          Finland            5
# 8           France           29
# 9          Germany           32
# 10           Italy           12
# 11           Japan           25
# 12           Korea           10
# 13          Mexico           10
# 14     Netherlands           20
# 15           Spain            9
# 16          Sweden           12
# 17     Switzerland           13
# 18          Taiwan           10
# 19  United Kingdom           25
# 20   United States          101

# %% [markdown]
# Geef een overzicht met daarin van de producten behorend tot het producttype ‘Cooking Gear’ per productnaam de totaal verkochte hoeveelheid en de gemiddelde verkoopprijs. Sorteer de uitkomst op totaal verkochte hoeveelheid. (4 kolommen, 10 rijen)

# %%
producten =  pd.merge(left=product, right=product_type, how='inner', left_on='PRODUCT_TYPE_CODE', right_on='PRODUCT_TYPE_CODE')
producten =  pd.merge(left=producten, right=order_details, how='inner', left_on='PRODUCT_NUMBER', right_on='PRODUCT_NUMBER')


producten['UNIT_PRICE'] = producten['UNIT_PRICE'].astype('double')

# producten.drop_duplicates()

f = producten["PRODUCT_TYPE_EN"] == "Cooking Gear"
producten = producten.loc[f, :]

producten['Hoeveelheid'] = 0
g = producten.groupby("PRODUCT_NAME", as_index=False)['QUANTITY'].sum()

d = producten.groupby("PRODUCT_NAME", as_index=False)['UNIT_PRICE'].agg(np.mean).round(2)


frame = pd.concat([g, d], axis=True)


frame = frame.loc[:, ~frame.columns.duplicated()].copy()
frame = frame.sort_values(by="QUANTITY", ascending=False)
frame
# Out:
#                 PRODUCT_NAME  QUANTITY  UNIT_PRICE
# 9        TrailChef Water Bag     41770        6.18
# 2              TrailChef Cup     31834        7.14
# 0          TrailChef Canteen     31712       12.18
# 6      TrailChef Kitchen Kit     25964       22.74
# 8         TrailChef Utensils     15928       17.73
# 4     TrailChef Double Flame     14510      136.60
# 1         TrailChef Cook Set     12700       52.61
# 7     TrailChef Single Flame     10614       65.09
# 5           TrailChef Kettle      9900       12.38
# 3  TrailChef Deluxe Cook Set      3744      123.54

# %% [markdown]
# Geef een overzicht met daarin van de verkopers behorend tot de verkoopafdeling uit ‘Amsterdam’ de voornaam en achternaam van de verkoper en zijn laagste en hoogste verkooptarget van 2022. (4 kolommen, 4 rijen)

# %%
frame = sales_branch.merge(sales_staff, left_on="SALES_BRANCH_CODE", how="inner", right_on="SALES_BRANCH_CODE")
df2 = frame.merge(target, left_on="SALES_STAFF_CODE", how="inner", right_on="SALES_STAFF_CODE")

filter = (df2['CITY'] == "Amsterdam") & (df2['SALES_YEAR'] == "2022")

df2 = df2.loc[filter, ["FIRST_NAME", "LAST_NAME", "SALES_STAFF_CODE", "SALES_TARGET"]]
df2['SALES_TARGET'] = df2['SALES_TARGET'].astype('int')

g = df2.groupby("SALES_STAFF_CODE", as_index=False)['SALES_TARGET'].agg({'min', 'max'})
g = g.drop(['SALES_STAFF_CODE'], axis='columns')
df2 = df2.drop_duplicates(["FIRST_NAME"]).reset_index(drop=True)


df3 = pd.concat([df2.loc[:, ["FIRST_NAME", "LAST_NAME"]], g], axis=1)
df3
# Out:
#   FIRST_NAME         LAST_NAME    max  min
# 0    Belinda  Jansen-Velasquez  34873   87
# 1      Ellen           Shapiro  25512   48
# 2        Jan         Haverkamp  24800   83
# 3      Maria          Laponder  19825   36

# %% [markdown]
# Geef een overzicht met daarin per land de naam van het land, de naam van de stad waar de verkoopafdeling is gevestigd (noem de kolomnaam in het overzicht ‘verkoper’) en het aantal steden waar zich klanten bevinden in dat land (noem de kolomnaam in het overzicht ‘klanten’) (3 kolommen, 29 rijen)

# %%
c = country

merged = c.merge(sales_branch, left_on='COUNTRY_CODE', right_on='COUNTRY_CODE', how='left').rename(columns={"CITY": "SALES_BRANCH_CITY"})
rt = merged.merge(retailer_site, left_on='COUNTRY_CODE', right_on='COUNTRY_CODE', how='left').rename(columns={"CITY": "RETAILER_CITY"})

rt = rt.drop_duplicates('RETAILER_CITY')
a = rt.groupby("COUNTRY")['RETAILER_CITY'].count()

a
# Out:
# COUNTRY
# Australia          6
# Austria            9
# Belgium            8
# Brazil             1
# Canada            16
# China              7
# Denmark            5
# Finland            5
# France            14
# Germany           18
# Italy              9
# Japan              5
# Korea              6
# Mexico             6
# Netherlands       15
# Spain              5
# Sweden            10
# Switzerland        9
# Taiwan             9
# United Kingdom     8
# United States     62
# Name: RETAILER_CITY, dtype: int64

# %% [markdown]
# ## Pythonvertalingen van SUBSELECT en UNION met o.a. for-loops

# %% [markdown]
# Geef een overzicht met daarin de voornaam en de achternaam van de medewerkers die nog nooit wat hebben verkocht (2 kolommen, 25 rijen)

# %%
df = pd.DataFrame(columns=["SALES_STAFF_CODE","FIRST_NAME","LAST_NAME","POSITION_EN","WORK_PHONE","EXTENSION","FAX","EMAIL","DATE_HIRED", "SALES_BRANCH_CODE", "TRIAL888"])
for index, row in sales_staff.iterrows():
    if order_header['SALES_STAFF_CODE'].str.contains(row['SALES_STAFF_CODE']).any() == False:
        df.loc[len(df.index)] = row
        # row


df.loc[:, ['FIRST_NAME', 'LAST_NAME']]
# Out:
#    FIRST_NAME      LAST_NAME
# 0      Walter         Taylor
# 1    Penelope        Tamrine
# 2       Polly         Linton
# 3       Gracy        Gellens
# 4        Kick        Kalkman
# 5       Karin      Bergström
# 6       Sally          White
# 7       Frank        Bretton
# 8     Georges  Saint-Germain
# 9        Alex      Rodriguez
# 10   Samantha          Floyd
# 11      Julie          Olsen
# 12      Corey         Wright
# 13    Estelle        Johnson
# 14       Greg        Belding
# 15      Julie        Béchard
# 16      Lucía          Reyna
# 17     Kazumi        Uragome
# 18      Alice         Walter

# %% [markdown]
# Geef een overzicht met daarin het aantal producten waarvan de marge lager is dan de gemiddelde marge van alle producten samen. Geef in het overzicht tevens aan wat de gemiddelde marge is van dit aantal producten waarvan de marge lager dan de gemiddelde marge van alle producten samen is. (1 kolom, 2 rijen)

# %%
p = product

p['MARGIN'] = p['MARGIN'].astype('float')
avg_margin = p['MARGIN'].mean()


mp = p.loc[p["MARGIN"] < avg_margin, :]

prod_num = len(mp)

mp_avg_margin = mp['MARGIN'].mean()

# 1 kolom is niet logisch bij deze vraag, vandaar 2
df = pd.DataFrame(columns=['aantal', 'marge'])


df.loc[len(df.index)] = [round(prod_num), mp_avg_margin]


df
# Out:
#    aantal     marge
# 0    59.0  0.292203

# %% [markdown]
# Geef een overzicht met daarin de namen van de producten die voor meer dan 500 (verkoopprijs) zijn verkocht maar nooit zijn teruggebracht. (1 kolom, 13 rijen)

# %%
p = product
merged = p.merge(order_details, left_on="PRODUCT_NUMBER", right_on="PRODUCT_NUMBER",  how='inner')

merged['UNIT_PRICE'] = merged['UNIT_PRICE'].astype('float')

f = merged['UNIT_PRICE'] > 500

merged = merged.loc[f, :]

merged = merged.drop_duplicates('PRODUCT_NUMBER')

n = []

for index, row in merged.iterrows():
    if row['ORDER_DETAIL_CODE'] in returned_item['ORDER_DETAIL_CODE']:
        n.append(row['ORDER_DETAIL_CODE'])

merged.loc[:, ['PRODUCT_NAME']]
# Out:
#                             PRODUCT_NAME
# 1226               Hailstorm Steel Irons
# 1646            Hailstorm Titanium Irons
# 2064          Lady Hailstorm Steel Irons
# 2371       Lady Hailstorm Titanium Irons
# 2664        Hailstorm Titanium Woods Set
# 3001           Hailstorm Steel Woods Set
# 3445   Lady Hailstorm Titanium Woods Set
# 3762      Lady Hailstorm Steel Woods Set
# 6810                           Star Dome
# 7271                        Star Gazer 2
# 7665                        Star Gazer 3
# 8110                        Star Gazer 6
# 20920                     Husky Rope 200

# %% [markdown]
# Geef een overzicht met daarin per (achternaam van) medewerker of hij/zij manager is of niet, door deze informatie toe te voegen als extra 'Ja/Nee'-kolom.<br>
# Hint: gebruik een for-loop waarin je o.a. bepaalt of het woord 'Manager' in de functie (position_en) staat. (2 kolommen, 102 rijen).

# %%
s = sales_staff

IS_MANAGER = []

for index, row in sales_staff.iterrows():
    if 'Manager' in row['POSITION_EN']:
        IS_MANAGER.append("Ja")
    else:
        IS_MANAGER.append("Nee")

s["IS_MANAGER"] = IS_MANAGER

s.loc[: , ['LAST_NAME','IS_MANAGER']]
# Out:
#       LAST_NAME IS_MANAGER
# 0    Savolainen        Nee
# 1           Kim        Nee
# 2          Choi        Nee
# 3           Kao        Nee
# 4          Fang        Nee
# ..          ...        ...
# 97     Iglesias        Nee
# 98        Lopes         Ja
# 99       Barros        Nee
# 100   Guimarães        Nee
# 101    Lindholm        Nee
#
# [102 rows x 2 columns]

# %% [markdown]
# Met de onderstaande code laat je Python het huidige jaar uitrekenen.

# %%
from datetime import date
date.today().year
# Out:
# 2024

# %% [markdown]
# Met de onderstaande code selecteer je op een bepaald jaartal uit een datum.

# %%
from datetime import datetime

date_str = '16-8-2013'
date_format = '%d-%m-%Y'
date_obj = datetime.strptime(date_str, date_format)

date_obj.year
# Out:
# 2013

# %% [markdown]
# Geef met behulp van bovenstaande hulpcode een overzicht met daarin op basis van het aantal jaar dat iemand in dienst is of een medewerker ‘kort in dienst’ (minder dan 25 jaar in dienst) of een ‘lang in dienst’ (groter gelijk dan 12 jaar in dienst) is. Geef daarbij per medewerker in een aparte kolom zowel ‘kort in dienst’ als ‘lang in dienst’ aan. Gebruik (wederom) een for-loop.<br>
# (2 kolommen, 102 rijen)

# %%
frame = sales_staff
frame.rename(columns={"FIRST_NAME": "Medewerker"}, inplace=True)
dienst_data = []

for index, row in frame.iterrows():
    frame["DATE_HIRED"] = pd.to_datetime(frame["DATE_HIRED"], dayfirst=True)

    if date.today().year - date.today().year - row["DATE_HIRED"].year >= 25:
        dienst_data.append("lang in dienst")
    else:
        dienst_data.append("kort in dienst")

frame["jaren_in_dienst"] = dienst_data
frame.loc[:, ["Medewerker", "jaren_in_dienst"]]
# Out:
#     Medewerker jaren_in_dienst
# 0       Tuomas  kort in dienst
# 1     Chang-ho  kort in dienst
# 2      Jung-ho  kort in dienst
# 3    Kwei-Ping  kort in dienst
# 4    Chin-Tsai  kort in dienst
# ..         ...             ...
# 97       Tomás  kort in dienst
# 98      Bayard  kort in dienst
# 99      Viviam  kort in dienst
# 100    Eduardo  kort in dienst
# 101     Helena  kort in dienst
#
# [102 rows x 2 columns]
